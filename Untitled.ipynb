# %% [markdown]
# # Section 2
# ## Problem 1
# ### 🎯 Goal
#
# We are given the loss function:
#
# L[ϕ] = Σᵢ (ϕ₀ + ϕ₁·xᵢ - yᵢ)²
#
# We want to compute the gradients:
#
# - ∂L/∂ϕ₀
# - ∂L/∂ϕ₁
#
# ---
#
# ### 🔹 Derivative with respect to ϕ₀
#
# **Step 1**: Define the error term:
#
# eᵢ = ϕ₀ + ϕ₁·xᵢ - yᵢ
#
# Then:
#
# L = Σᵢ eᵢ²
#
# **Step 2**: Apply the chain rule:
#
# ∂L/∂ϕ₀ = Σᵢ 2·eᵢ · ∂eᵢ/∂ϕ₀
#
# **Step 3**: Derivative of eᵢ with respect to ϕ₀ is:
#
# ∂eᵢ/∂ϕ₀ = 1
#
# **Step 4**: Combine:
#
# ∂L/∂ϕ₀ = 2 · Σᵢ (ϕ₀ + ϕ₁·xᵢ - yᵢ)
#
# ---
#
# ### 🔹 Derivative with respect to ϕ₁
#
# **Step 1**: Same eᵢ as above:
#
# eᵢ = ϕ₀ + ϕ₁·xᵢ - yᵢ
#
# **Step 2**: Chain rule:
#
# ∂L/∂ϕ₁ = Σᵢ 2·eᵢ · ∂eᵢ/∂ϕ₁
#
# **Step 3**: Derivative of eᵢ with respect to ϕ₁ is:
#
# ∂eᵢ/∂ϕ₁ = xᵢ
#
# **Step 4**: Combine:
#
# ∂L/∂ϕ₁ = 2 · Σᵢ (ϕ₀ + ϕ₁·xᵢ - yᵢ) · xᵢ
#
# ---
#
# ### ✅ Final Answer
#
# - ∂L/∂ϕ₀ = 2 · Σᵢ (ϕ₀ + ϕ₁·xᵢ - yᵢ)
# - ∂L/∂ϕ₁ = 2 · Σᵢ (ϕ₀ + ϕ₁·xᵢ - yᵢ) · xᵢ
#
#
# ## Problem 2
# We are minimizing the loss function:
#
# L(ϕ₀, ϕ₁) = ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)²
#
# To find the minimum, we compute the gradients and set them to zero.
#
# ---
#
# ### 🔹 Step 1: Compute the gradients
#
# ∂L/∂ϕ₀ = 2 · ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)
# Set to 0:
# ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ) = 0                         (Equation ①)
#
# ∂L/∂ϕ₁ = 2 · ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)·xᵢ
# Set to 0:
# ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)·xᵢ = 0                    (Equation ②)
#
# ---
#
# ### 🔹 Step 2: Expand Equation ①
#
# ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)
# = ∑ᵢ ϕ₀ + ∑ᵢ ϕ₁·xᵢ − ∑ᵢ yᵢ
# = ϕ₀·∑ᵢ 1 + ϕ₁·∑ᵢ xᵢ − ∑ᵢ yᵢ
# = 0
#
# So:
# ϕ₀·∑ᵢ 1 + ϕ₁·∑ᵢ xᵢ = ∑ᵢ yᵢ                  (Equation ③)
#
# ---
#
# ### 🔹 Step 3: Expand Equation ②
#
# ∑ᵢ (ϕ₀ + ϕ₁·xᵢ − yᵢ)·xᵢ
# = ∑ᵢ ϕ₀·xᵢ + ∑ᵢ ϕ₁·xᵢ² − ∑ᵢ yᵢ·xᵢ
# = ϕ₀·∑ᵢ xᵢ + ϕ₁·∑ᵢ xᵢ² − ∑ᵢ xᵢ·yᵢ
# = 0
#
# So:
# ϕ₀·∑ᵢ xᵢ + ϕ₁·∑ᵢ xᵢ² = ∑ᵢ xᵢ·yᵢ             (Equation ④)
#
# ---
#
# ### 🔹 Step 4: Solve the system (Equation ③ and ④)
#
# From Equation ③:
# ϕ₀ = (∑ᵢ yᵢ − ϕ₁·∑ᵢ xᵢ) / ∑ᵢ 1
#
# Substitute into Equation ④:
#
# [(∑ᵢ yᵢ − ϕ₁·∑ᵢ xᵢ) / ∑ᵢ 1] · ∑ᵢ xᵢ + ϕ₁·∑ᵢ xᵢ² = ∑ᵢ xᵢ·yᵢ
#
# Multiply both sides by ∑ᵢ 1:
#
# (∑ᵢ yᵢ − ϕ₁·∑ᵢ xᵢ) · ∑ᵢ xᵢ + ϕ₁·(∑ᵢ 1)·∑ᵢ xᵢ² = (∑ᵢ 1)·∑ᵢ xᵢ·yᵢ
#
# Distribute:
#
# (∑ᵢ yᵢ)(∑ᵢ xᵢ) − ϕ₁·(∑ᵢ xᵢ)² + ϕ₁·(∑ᵢ 1)(∑ᵢ xᵢ²) = (∑ᵢ 1)(∑ᵢ xᵢ·yᵢ)
#
# Group terms with ϕ₁:
#
# ϕ₁·[ (∑ᵢ 1)(∑ᵢ xᵢ²) − (∑ᵢ xᵢ)² ] = (∑ᵢ 1)(∑ᵢ xᵢ·yᵢ) − (∑ᵢ yᵢ)(∑ᵢ xᵢ)
#
# ---
#
# ### ✅ Final solution:
#
# ϕ₁ = [ (∑ᵢ 1)(∑ᵢ xᵢ·yᵢ) − (∑ᵢ xᵢ)(∑ᵢ yᵢ) ]
#        /
#    [ (∑ᵢ 1)(∑ᵢ xᵢ²) − (∑ᵢ xᵢ)² ]
#
# ϕ₀ = (∑ᵢ yᵢ − ϕ₁·∑ᵢ xᵢ) / ∑ᵢ 1
#
# ---
# ### 🔍 Why this only works for linear models
#
# For linear regression, this system is quadratic in ϕ0,ϕ1ϕ0​,ϕ1​, so we can solve it analytically. For more complex models (e.g., neural networks), the loss surface is non-convex, and we must use iterative optimization like gradient descent.
#
# ## Problem 3
# We flip the usual direction of linear regression.
#
# ---
#
# ### 🔹 1. Generative Model
#
# Instead of predicting `y` from `x`, we now predict `x` from `y`.
#
# **Model**:
# x = ϕ₀ + ϕ₁·y
#
# This is the generative form.
#
# ---
#
# ### 🔹 2. New Loss Function
#
# Since we're predicting `x` from `y`, the loss becomes:
#
# L(ϕ₀, ϕ₁) = ∑ (xᵢ − (ϕ₀ + ϕ₁·yᵢ))²
#
# This is the same structure as ordinary least squares, but with inputs and outputs swapped.
#
# ---
#
# ### 🔹 3. Inverse Function
#
# To perform inference (i.e., recover `y` from a new `x`), we invert the function:
#
# x = ϕ₀ + ϕ₁·y
# ⇒ y = (x − ϕ₀) / ϕ₁
#
# So the inverse function is:
#
# y = g⁻¹(x, ϕ) = (x − ϕ₀) / ϕ₁
#
# ---
#
# ### 🔹 4. Will the Predictions Match the Discriminative Model?
#
# **No**, in general they will not.
#
# Even though the equations look symmetric, the **error is minimized in different directions**:
#
# - Discriminative regression (y = ϕ₀ + ϕ₁·x) minimizes **vertical** error (difference in y).
# - Generative regression (x = ϕ₀ + ϕ₁·y) minimizes **horizontal** error (difference in x).
#
# These only match if the data lies exactly on a line (i.e., perfect correlation).
#
# ---
#
# ### 🔹 5. Python Example: Compare Both Methods

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
x = np.array([1, 2, 3])
y = np.array([2, 2.5, 4])

# Discriminative: y = a + b*x
A = np.vstack([x, np.ones(len(x))]).T
b_discriminative, a_discriminative = np.linalg.lstsq(A, y, rcond=None)[0]

# Generative: x = a + b*y ⇒ solve x ~ y, then invert
A_gen = np.vstack([y, np.ones(len(y))]).T
b_gen, a_gen = np.linalg.lstsq(A_gen, x, rcond=None)[0]

# Invert to get y = (x - a_gen) / b_gen
b_inverted = 1 / b_gen
a_inverted = -a_gen / b_gen

# Compare lines
x_vals = np.linspace(0, 4, 100)
y_disc = a_discriminative + b_discriminative * x_vals
y_gen = a_inverted + b_inverted * x_vals

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x_vals, y_disc, label="Discriminative", color="blue")
plt.plot(x_vals, y_gen, label="Generative (inverted)", color="red", linestyle="--")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Discriminative vs. Generative Linear Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# apenas se os pontos estiverem alinhados na diagonal, os dois são iguais

# %% [markdown]
# # Section 3

# %% [markdown]
# ## Problem 1 — Effect of Changing the Activation Function
#
# We are given the model:
#
# $$
# y = \phi_0 + \phi_1 \cdot a(\theta_{10} + \theta_{11}x)
#           + \phi_2 \cdot a(\theta_{20} + \theta_{21}x)
#           + \phi_3 \cdot a(\theta_{30} + \theta_{31}x)
# $$
#
# This is a neural network with:
# - Input: $x$
# - Hidden layer: 3 neurons
# - Activation function: $a(z)$
# - Output: weighted sum of activations
#
# ---
#
# ### 🔹 Case 1: Linear Activation Function
#
# Assume:
#
# $$
# a(z) = \psi_0 + \psi_1 z
# $$
#
# Substitute into the model:
#
# $$
# \begin{aligned}
# y &= \phi_0
# + \phi_1 (\psi_0 + \psi_1(\theta_{10} + \theta_{11}x)) \\
#   &\quad + \phi_2 (\psi_0 + \psi_1(\theta_{20} + \theta_{21}x)) \\
#   &\quad + \phi_3 (\psi_0 + \psi_1(\theta_{30} + \theta_{31}x))
# \end{aligned}
# $$
#
# Expand:
#
# $$
# \begin{aligned}
# y &= \phi_0
# + \psi_0(\phi_1 + \phi_2 + \phi_3) \\
#   &\quad + \psi_1(\phi_1\theta_{10} + \phi_2\theta_{20} + \phi_3\theta_{30}) \\
#   &\quad + \psi_1(\phi_1\theta_{11} + \phi_2\theta_{21} + \phi_3\theta_{31})x
# \end{aligned}
# $$
#
# This is of the form:
#
# $$
# y = A + Bx
# $$
#
# ✅ **Conclusion:** The result is a **linear function of $x$**. The network becomes a linear model.
#
# ---
#
# ### 🔹 Case 2: Identity Activation Function
#
# Assume:
#
# $$
# a(z) = z
# $$
#
# Then the model becomes:
#
# $$
# y = \phi_0 + \phi_1(\theta_{10} + \theta_{11}x)
#           + \phi_2(\theta_{20} + \theta_{21}x)
#           + \phi_3(\theta_{30} + \theta_{31}x)
# $$
#
# Group terms:
#
# $$
# y = (\phi_0 + \phi_1\theta_{10} + \phi_2\theta_{20} + \phi_3\theta_{30})
#   + (\phi_1\theta_{11} + \phi_2\theta_{21} + \phi_3\theta_{31})x
# $$
#
# This is again:
#
# $$
# y = A + Bx
# $$
#
# ✅ **Conclusion:** Using no activation (just identity) again results in a **purely linear model**.
#
# ---
#
# ### 🧠 Summary Table
#
# | Activation Function            | Output Mapping          |
# |-------------------------------|--------------------------|
# | $a(z) = \psi_0 + \psi_1 z$     | Linear in $x$            |
# | $a(z) = z$                     | Linear in $x$            |
#
# ➡️ In both cases, the network **loses its nonlinearity** and becomes a simple linear function.

# %% [markdown]
# ## Problem 2
#
# <img src="table_3_2.png" alt="Drawing"/>

# %% [markdown]
# Basicamente é so ir vendo pelo x, da imagem j, e perceber se os valores de a) a i) são 0 (estão inativos) ou dão algum valor, ativos.
# Por exemplo no sombreado, o h) está inativo

# %% [markdown]
# ## Problem 3

# %% [markdown]
# We are given the output function:
#
# $$
# y = \phi_0 + \phi_1 h_1 + \phi_2 h_2 + \phi_3 h_3
# $$
#
# where each hidden unit is defined as:
#
# $$
# h_i = a(\theta_{i0} + \theta_{i1}x)
# $$
#
# Assume the activation function is **ReLU**:
#
# $$
# a(z) = \max(0, z)
# $$
#
# ---
#
# ### 🔹 Positions of the “joints”
#
# Each ReLU unit activates (jumps from 0 to linear) when its argument crosses 0:
#
# $$
# \theta_{i0} + \theta_{i1}x = 0
# \quad \Rightarrow \quad
# x = -\frac{\theta_{i0}}{\theta_{i1}}
# $$
#
# So the **joint positions** occur at:
#
# - First joint:  $x = -\frac{\theta_{10}}{\theta_{11}}$
# - Second joint: $x = -\frac{\theta_{20}}{\theta_{21}}$
# - Third joint:  $x = -\frac{\theta_{30}}{\theta_{31}}$
#
# ---

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Como tu o que for negativo passa a 0, quando for 0, o α nao tem qualquer efeito, logo é igual meter o α dentro ou fora do relu

# %% [markdown]
# ## Problem 6

# %% [markdown]
# We are given a shallow neural network:
#
# ### Hidden unit:
# $$
# h_1(x) = a(\theta_{10} + \theta_{11} x)
# $$
#
# ### Output:
# $$
# y = \phi_0 + \phi_1 \cdot h_1(x)
# $$
#
# Now we apply the transformation:
#
# - Multiply both $\theta_{10}$ and $\theta_{11}$ by a constant $\alpha$
# - Divide $\phi_1$ by the same constant $\alpha$
#
# ---
#
# ### 🔹 Case 1: Positive scaling ($\alpha > 0$)
#
# We substitute:
#
# $$
# h_1(x) = a(\alpha \theta_{10} + \alpha \theta_{11} x) = a\left(\alpha (\theta_{10} + \theta_{11}x)\right)
# $$
#
# Using the ReLU property:
# If $a(z) = \max(0, z)$ and $\alpha > 0$, then:
#
# $$
# a(\alpha z) = \alpha \cdot a(z)
# $$
#
# So:
#
# $$
# h_1(x) = \alpha \cdot a(\theta_{10} + \theta_{11}x)
# $$
#
# Now the output becomes:
#
# $$
# y = \phi_0 + \frac{\phi_1}{\alpha} \cdot h_1(x)
# = \phi_0 + \frac{\phi_1}{\alpha} \cdot \alpha \cdot a(\theta_{10} + \theta_{11}x)
# = \phi_0 + \phi_1 \cdot a(\theta_{10} + \theta_{11}x)
# $$
#
# ✅ **Conclusion:** If $\alpha > 0$, the scaling **cancels out**, and the network behaves **exactly the same**.
#
# ---
#
# ### 🔸 Case 2: Negative scaling ($\alpha < 0$)
#
# Now we flip the sign of the input:
#
# $$
# h_1(x) = a(\alpha (\theta_{10} + \theta_{11}x))
# $$
#
# But since $\alpha < 0$, the argument inside the ReLU flips:
#
# - If $\theta_{10} + \theta_{11}x > 0$, then $\alpha (\cdot) < 0$ ⇒ $a(\cdot) = 0$
# - If $\theta_{10} + \theta_{11}x < 0$, then $\alpha (\cdot) > 0$ ⇒ $a(\cdot) > 0$
#
# So:
#
# - The ReLU now activates in the **opposite region**
# - The output becomes a **different function**
# - The shape is a **mirror** of the original
#
# ❌ **Conclusion:** If $\alpha < 0$, the network output **changes**, because ReLU is **not symmetric**.
#
# ---
#
# ### ✅ Summary Table
#
# | $\alpha$            | Effect on Output Function                            |
# |---------------------|-------------------------------------------------------|
# | $\alpha > 0$        | No change — scaling cancels                          |
# | $\alpha < 0$        | Function changes — ReLU flips active region          |

# %% [markdown]
# ## Problem 7

# %% [markdown]
# **No**, the least squares loss for the network in Equation 3.1 **does not have a unique minimum**.
#
# #### 🔹 Reasons:
#
# 1. **Non-convex loss surface**:
#    Due to the nonlinear activation function (e.g. ReLU), the model is not convex in its parameters, so the loss surface can contain multiple local minima and saddle points.
#
# 2. **Parameter scaling invariance**:
#    For each hidden unit, scaling $\theta_{i0}, \theta_{i1}$ by $\alpha$ and dividing $\phi_i$ by $\alpha$ gives the same function.
#    So multiple parameter combinations lead to the **same output** and **same loss**.
#
# 3. **Hidden unit permutation symmetry**:
#    Swapping the roles of hidden units (e.g., exchanging $\phi_1$ with $\phi_2$ and their corresponding $\theta$'s) gives the same model output, so again, multiple parameter sets yield identical loss.
#
# #### ✅ Conclusion:
# The loss function may have **multiple global minima** and **many equally good parameter sets**. There is not a single "best" set of parameters.

# %% [markdown]
# ## Problem 8

# %% [markdown]
# We consider the network:
#
# $$
# y = \phi_0 + \phi_1 \cdot a(\theta_{10} + \theta_{11}x) + \phi_2 \cdot a(\theta_{20} + \theta_{21}x) + \phi_3 \cdot a(\theta_{30} + \theta_{31}x)
# $$
#
# With parameters:
#
# - $\phi = \{-0.23, -1.3, 1.3, 0.66\}$
# - $\theta = \{-0.2, 0.4, -0.9, 0.9, 1.1, -0.7\}$
#   (i.e., $\theta_{10}, \theta_{11}, \theta_{20}, \theta_{21}, \theta_{30}, \theta_{31}$)
#
# We analyze the result of replacing ReLU with the following:
#
# ---
#
# ### 🔹 1. Heaviside Step Function
#
# Defined as:
#
# $$
# \text{heaviside}(z) =
# \begin{cases}
# 0 & \text{if } z < 0 \\
# 1 & \text{if } z \geq 0
# \end{cases}
# $$
#
# #### 🔸 Effect:
# - Each hidden unit outputs either **0 or 1**
# - Output $y$ becomes a **piecewise constant function**
# - Up to 3 hidden units => up to **8 possible levels** (combinations of on/off)
# - Transitions are sharp, **discontinuous jumps**
#
# #### 🔸 Function Family:
# - Step functions
# - Useful for approximating classification boundaries or simple rules
#
# ---
#
# ### 🔹 2. Hyperbolic Tangent ($\tanh$)
#
# Defined as:
#
# $$
# \tanh(z) = \frac{e^z - e^{-z}}{e^z + e^{-z}} \in (-1, 1)
# $$
#
# #### 🔸 Effect:
# - Each unit outputs a **smooth curve** from -1 to 1
# - The final output is a **smooth nonlinear function**
# - No hard breakpoints — only gradual bends
#
# #### 🔸 Function Family:
# - Smooth S-shaped functions
# - Can represent gradual trends and non-linear dependencies
#
# ---
#
# ### 🔹 3. Rectangular Window Function
#
# Defined as:
#
# $$
# \text{rect}(z) =
# \begin{cases}
# 0 & z < 0 \\
# 1 & 0 \leq z \leq 1 \\
# 0 & z > 1
# \end{cases}
# $$
#
# #### 🔸 Effect:
# - Each unit produces a **flat bump** (1) in a specific input range
# - Output is a **sum of flat-topped pulses**
# - Can isolate contributions to narrow regions of $x$
#
# #### 🔸 Function Family:
# - Localized bumps or flat peaks
# - Good for building **histogram-like** or spatially-aware functions
#
# ---
#
# ### ✅ Summary Table
#
# | Activation Function | Output Behavior             | Function Type                         |
# |---------------------|-----------------------------|----------------------------------------|
# | Heaviside           | Piecewise constant           | Step functions with jumps              |
# | Tanh                | Smooth, continuous           | S-shaped nonlinear functions           |
# | Rect                | Localized flat peaks         | Bumpy/histogram-like, spatially local  |
#
# ---
#
# ### 🧠 Informal Insight
#
# - **ReLU** builds **piecewise linear** functions
# - **Heaviside** builds **discrete step** functions
# - **Tanh** builds **smooth, nonlinear** curves
# - **Rect** builds **piecewise constant, localized bump** functions
#
# Each activation expands or restricts the kinds of functions the network can express — from sharp rule-like logic to smooth approximations or localized detection.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Input range
x = np.linspace(-1, 2, 500)

# Parameters from the problem
phi_0 = -0.23
phi_1 = -1.3
phi_2 = 1.3
phi_3 = 0.66

theta_10, theta_11 = -0.2, 0.4
theta_20, theta_21 = -0.9, 0.9
theta_30, theta_31 = 1.1, -0.7

# Pre-activations for each hidden unit
z1 = theta_10 + theta_11 * x
z2 = theta_20 + theta_21 * x
z3 = theta_30 + theta_31 * x

# Activation functions
def heaviside(z):
    return np.where(z >= 0, 1.0, 0.0)

def rect(z):
    return np.where((z >= 0) & (z <= 1), 1.0, 0.0)

def tanh(z):
    return np.tanh(z)

# Output functions
def output(a1, a2, a3):
    return phi_0 + phi_1 * a1 + phi_2 * a2 + phi_3 * a3

# Compute outputs
y_heaviside = output(heaviside(z1), heaviside(z2), heaviside(z3))
y_tanh = output(tanh(z1), tanh(z2), tanh(z3))
y_rect = output(rect(z1), rect(z2), rect(z3))

# Plotting
fig, axs = plt.subplots(3, 1, figsize=(8, 10), sharex=True)

axs[0].plot(x, y_heaviside, label="Heaviside", color="darkorange")
axs[0].set_title("Output with Heaviside Activation")
axs[0].set_ylabel("y")
axs[0].grid(True)

axs[1].plot(x, y_tanh, label="Tanh", color="teal")
axs[1].set_title("Output with Tanh Activation")
axs[1].set_ylabel("y")
axs[1].grid(True)

axs[2].plot(x, y_rect, label="Rect", color="purple")
axs[2].set_title("Output with Rect Activation")
axs[2].set_xlabel("x")
axs[2].set_ylabel("y")
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Problem 9

# %% [markdown]
# We are analyzing the output function from the shallow neural network:
#
# $$
# y(x) = \phi_0 + \phi_1 h_1(x) + \phi_2 h_2(x) + \phi_3 h_3(x)
# $$
#
# Where:
#
# $$
# h_i(x) = \text{ReLU}(\theta_{i0} + \theta_{i1} x) = \max(0, \theta_{i0} + \theta_{i1} x)
# $$
#
# ---
#
# ### 🔹 From the figure (3.3j), we observe:
#
# | Region     | Active Units            | Slope Expression                           |
# |------------|--------------------------|---------------------------------------------|
# | Region 1   | $h_3$ only               | $\phi_3 \theta_{31}$                        |
# | Region 2   | $h_1$ and $h_3$ active   | $\phi_1 \theta_{11} + \phi_3 \theta_{31}$   |
# | Region 3   | $h_1$, $h_2$ and $h_3$ active | $\phi_1 \theta_{11} + \phi_2 \theta_{21} + \phi_3 \theta_{31}$ |
# | Region 4   | $h_1$ and $h_2$ active   | $\phi_1 \theta_{11} + \phi_2 \theta_{21}$   |
#
# ---
#
# Region 3 = Region 1 + Region 4

# %% [markdown]
# ## Problem 10

# %% [markdown]
# A shallow neural network with 3 ReLU hidden units typically creates **4 linear regions**.
# However, fewer regions can occur under the following circumstances:
#
# ---
#
# ### 🔹 1. A hidden unit **never activates**
# - If $\theta_{i0} + \theta_{i1}x < 0$ for all $x$ in the input domain, then:
#   $$ h_i(x) = 0 \quad \Rightarrow \phi_i h_i(x) = 0 $$
# - The unit has no effect, and its activation point doesn't create a region change.
#
# ---
#
# ### 🔹 2. A hidden unit is **always active**
# - If $\theta_{i0} + \theta_{i1}x > 0$ for all $x$, then:
#   $$ h_i(x) = \theta_{i0} + \theta_{i1}x $$
# - This behaves like a linear term and doesn't introduce a kink.
#
# ---
#
# ### 🔹 3. Two units activate at the **same input**
# - If two breakpoints overlap:
#   $$ -\frac{\theta_{i0}}{\theta_{i1}} = -\frac{\theta_{j0}}{\theta_{j1}} $$
# - Then two region transitions collapse into one.
#
# ---
#
# ### 🔹 4. The hidden unit's effect is **canceled in the output**
# - If $\phi_i = 0$ or multiple units produce changes that cancel out, their activation doesn't create a visible change in $y(x)$.
#
# ---
#
# ### ✅ Conclusion:
#
# Although 3 ReLU units can theoretically create 4 linear regions, the network may produce fewer if:
# - Units are always or never active
# - Breakpoints overlap
# - Output weights cancel effects

# %% [markdown]
# ## Problem 11

# %% [markdown]
# We analyze the network:
#
# - 1 input node: $x$
# - 4 hidden units: $h_1, h_2, h_3, h_4$
# - 2 output units: $y_1, y_2$
#
# ### 🔹 Do biases exist?
#
# Yes — based on context from earlier problems and typical network structure, we assume **each neuron has a bias**.
#
# ---
#
# ### 🔹 Parameters from Input to Hidden:
#
# Each hidden unit gets:
# - 1 weight from input
# - 1 bias
#
# So:
# $$
# (1 + 1) \times 4 = 8 \text{ parameters}
# $$
#
# ---
#
# ### 🔹 Parameters from Hidden to Output:
#
# Each output unit gets:
# - 4 weights (from the 4 hidden units)
# - 1 bias
#
# So:
# $$
# (4 + 1) \times 2 = 10 \text{ parameters}
# $$
#
# ---
#
# ### ✅ Total number of parameters:
#
# $$
# 8 + 10 = \boxed{18 \text{ parameters}}
# $$

# %% [markdown]
# ## Problem 13

# %% [markdown]
# <img src="image_3_13.png" alt="Drawing"/>
#
# Each hidden unit $h_i$ is active when:
# $$
# \theta_{i0} + \theta_{i1}x_1 + \theta_{i2}x_2 \geq 0
# $$
#
# This creates **7 regions** based on different combinations of hidden unit activations.
#
# | Region | $h_1$ | $h_2$ | $h_3$ | Activation Pattern |
# |--------|-------|-------|-------|--------------------|
# | R1     | 0     | 0     | 0     | (0, 0, 0)          |
# | R2     | 1     | 0     | 0     | (1, 0, 0)          |
# | R3     | 0     | 1     | 0     | (0, 1, 0)          |
# | R4     | 1     | 1     | 0     | (1, 0, 1)          |
# | R5     | 1     | 1     | 1     | (0, 0, 1)          |
# | R6     | 0     | 1     | 1     | (1, 1, 1)          |
# | R7     | 0     | 0     | 1     | (1, 1, 1)          |
#
# ✅ Each row indicates whether the hidden units are **active (1)** or **inactive (0)** in that region.

# %% [markdown]
# ## Problem 14

# %% [markdown]
# We define the network in two layers:
#
# ---
#
# ### 🔹 Hidden Layer (3 units):
#
# Each hidden unit receives inputs $x_1, x_2, x_3$ and applies an activation function $a(z)$ (e.g. ReLU):
#
# 1. $h_1 = a(\theta_{10} + \theta_{11} x_1 + \theta_{12} x_2 + \theta_{13} x_3)$
# 2. $h_2 = a(\theta_{20} + \theta_{21} x_1 + \theta_{22} x_2 + \theta_{23} x_3)$
# 3. $h_3 = a(\theta_{30} + \theta_{31} x_1 + \theta_{32} x_2 + \theta_{33} x_3)$
#
# ---
#
# ### 🔹 Output Layer (2 units):
#
# Each output is a linear combination of the hidden units:
#
# 4. $y_1 = \phi_{10} + \phi_{11} h_1 + \phi_{12} h_2 + \phi_{13} h_3$
# 5. $y_2 = \phi_{20} + \phi_{21} h_1 + \phi_{22} h_2 + \phi_{23} h_3$
#
# ---
#
# ### ✅ Total parameters:
# - 12 weights from input to hidden + 3 biases = 15
# - 6 weights from hidden to output + 2 biases = 8
# - **Total = 15 + 5 = 20 parameters**

# %% [markdown]
# ## Problem 15

# %% [markdown]
# We consider the ReLU network in Figure 3.11 with:
#
# - Input dimension: $d = 3$
# - Number of hidden units: $H = 3$
#
# The number of linear regions in the input space created by ReLU activations is:
#
# $$
# \sum_{j=0}^{d} \binom{H}{j}
# = \binom{3}{0} + \binom{3}{1} + \binom{3}{2} + \binom{3}{3}
# = 1 + 3 + 3 + 1 = \boxed{8}
# $$
#
# $$
# \binom{n}{k} = \frac{n!}{k!(n - k)!}
# $$

# %% [markdown]
# ## Problem 17

# %% [markdown]
# Di \*  D + D + D \* Do + Do

# %% [markdown]
#  ## Problem 18

# %% [markdown]
# We use Zaslavsky’s result:
#
# > The maximum number of regions created by $D$ hyperplanes in $D_i$-dimensional space is:
#
# $$
# R = \sum_{j=0}^{D_i} \binom{D}{j}
# $$
#
# ---
#
# ### 🔹 Given:
#
# - Input dimension: $D_i = 2$
# - Number of hidden units: $D = 3$ (initial), then $D = 5$ (extended)
#
# ---
#
# ### 🔸 Case 1: $D = 3$
#
# $$
# R = \binom{3}{0} + \binom{3}{1} + \binom{3}{2} = 1 + 3 + 3 = \boxed{7}
# $$
#
# ✅ Confirms the 7 regions shown in Figure 3.8j.
#
# ---
#
# ### 🔸 Case 2: $D = 5$
#
# $$
# R = \binom{5}{0} + \binom{5}{1} + \binom{5}{2} = 1 + 5 + 10 = \boxed{16}
# $$
#
# ✅ With 5 hidden units and 2D input, the network can create up to **16 linear regions**.

# %% [markdown]
# # Section 4

# %% [markdown]
# ## Problem 2

# %% [markdown]
# The figure represents a multi-layer neural network with specified layer widths.
#
# The four architectural **hyperparameters** (not learned during training) are:
#
# 1. $D_1 = 4$ — Number of hidden units in the first hidden layer
# 2. $D_2 = 2$ — Number of hidden units in the second hidden layer
# 3. $D_3 = 3$ — Number of hidden units in the third hidden layer
# 4. $D_o = 2$ — Output dimensionality (number of output units)
#
# These hyperparameters define the **width** of each layer in the network.

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### Given:
# - Input dimension: $D_i = 5$
# - Output dimension: $D_o = 4$
# - Hidden layers: $D_1 = 20$, $D_2 = 10$, $D_3 = 7$
#
# ---
#
# ### 🔹 Equation form (layer-by-layer, like Equation 4.15):
#
# $$
# \begin{aligned}
# h_1 &= a(\beta_0 + \Omega_0 x) \\
# h_2 &= a(\beta_1 + \Omega_1 h_1) \\
# h_3 &= a(\beta_2 + \Omega_2 h_2) \\
# y   &= \beta_3 + \Omega_3 h_3
# \end{aligned}
# $$
#
# ---
#
# ### 🔹 Single function form (like Equation 4.16):
#
# $$
# y = \beta_3 + \Omega_3 \cdot a \left( \beta_2 + \Omega_2 \cdot a \left( \beta_1 + \Omega_1 \cdot a \left( \beta_0 + \Omega_0 x \right) \right) \right)
# $$
#
# ---
#
# ### 🔹 Parameter Dimensions:
#
# | Parameter     | Description             | Shape         |
# |---------------|--------------------------|---------------|
# | $\Omega_0$     | input $\rightarrow$ layer 1 | $20 \times 5$  |
# | $\beta_0$      | bias for layer 1         | $20$           |
# | $\Omega_1$     | layer 1 $\rightarrow$ layer 2 | $10 \times 20$ |
# | $\beta_1$      | bias for layer 2         | $10$           |
# | $\Omega_2$     | layer 2 $\rightarrow$ layer 3 | $7 \times 10$  |
# | $\beta_2$      | bias for layer 3         | $7$            |
# | $\Omega_3$     | layer 3 $\rightarrow$ output | $4 \times 7$   |
# | $\beta_3$      | output bias              | $4$            |

# %% [markdown]
# ## Problem 5

# %% [markdown]
# The number of hidden units in each layer is referred to as the width of the network,
# and the number of hidden layers as the depth.

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Given:
# - Input dimension: $D_i = 1$
# - Output dimension: $D_o = 1$
# - $K = 10$ hidden layers
# - Width $D = 10$ hidden units per layer
#
# ---
#
# ### 🔹 Case A: Increase **depth** by 1 (to $K = 11$)
#
# - Adds one more $10 \times 10 = 100$ weight matrix
# - Total increase: **100 weights**
#
# ---
#
# ### 🔸 Case B: Increase **width** by 1 (to $D = 11$)
#
# - Input layer: $11 \times 1 = 11$
# - Hidden layers: $9 \times 121 = 1089$
# - Output layer: $1 \times 11 = 11$
# - Total increase: **1111 - 920 = 191 weights**
#
# ---
#
# ### ✅ Conclusion:
#
# Increasing the **width** by one adds **more weights** than increasing the **depth** by one.
# So, **width impacts parameter count more than depth** in this case.

# %% [markdown]
# We compute the layer output (before activation) as:
#
#     h=W⋅x+b
#
#
# The weights are all the entries in matrix W
#
# The biases are in vector b

# %% [markdown]
# ## Problem 7

# %% [markdown]
# We use:
#
# $$
# y = \phi_0 + \phi_1 a(\theta_{10} + \theta_{11}x)
#       + \phi_2 a(\theta_{20} + \theta_{21}x)
#       + \phi_3 a(\theta_{30} + \theta_{31}x)
# $$
#
# To implement the identity function $y = x$ on the interval $x \in [0, 2]$.
#
# ---
#
# ### ✅ Choose Parameters:
#
# (lazy answear
#
# - $\phi_0 = 0$
# - $\phi_1 = 1$, $\theta_{10} = 0$,  $\theta_{11} = 1$
# - $\phi_2 = 0$
# - $\phi_3 = 0$
#
# ---
#
#
# x = y when relu is activated, > 0

# %% [markdown]
# ## Problem 8

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x
x = np.linspace(0, 1, 500)

# Define the hidden unit activations
def h1(x): return np.maximum(0, x - 1/6)
def h2(x): return np.maximum(0, x - 2/6)
def h3(x): return np.maximum(0, 4/6 - x)

# Define the final output y(x)
y = 1.4 - 3* h1(x) + 2 *h2(x) - 2* h3(x)

# Plot the function
plt.figure(figsize=(8, 4))
plt.plot(x, y, color='darkorange')
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)
plt.axvline(1/6, color='lightgray', linestyle='--')
plt.axvline(2/6, color='lightgray', linestyle='--')
plt.axvline(4/6, color='lightgray', linestyle='--')
plt.title("Output of ReLU Network (4 Linear Regions)")
plt.xlabel("Input $x$")
plt.ylabel("Output $y$")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔸 Composing the Network:
#
# If we define $f(x) = y(x)$, then:
#
# - $f(x)$ has 4 linear regions
# - $f(f(x))$ has up to $4^2 = 16$ regions
# - $f^K(x)$ (composed $K$ times) has up to $\boxed{4^K}$ regions

# %% [markdown]
# ## Problem 9

# %% [markdown]
# It's impossible to create a function with three linear regions that oscillates back and forth between output values of zero and one using a shallow network with two hidden units

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x
x = np.linspace(0, 1, 500)

# Define the hidden unit activations
def h1(x): return np.maximum(0, x - 1/6)
def h2(x): return np.maximum(0, x - 2/6)
def h3(x): return np.maximum(0, 4/6 - x)

# Define the final output y(x)
y = 1.4 - 3* h1(x) + 0 *h2(x) - 2* h3(x)

# Plot the function
plt.figure(figsize=(8, 4))
plt.plot(x, y, color='darkorange')
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)
plt.axvline(1/6, color='lightgray', linestyle='--')
plt.axvline(4/6, color='lightgray', linestyle='--')
plt.title("Output of ReLU Network (4 Linear Regions)")
plt.xlabel("Input $x$")
plt.ylabel("Output $y$")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# It's possible to create a function with five linear regions that oscillates
# in the same way using a shallow network with four hidden units

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x
x = np.linspace(0, 1, 500)

# Define the hidden unit activations
def h1(x): return np.maximum(0, x - 1/6)
def h2(x): return np.maximum(0, x - 2/6)
def h3(x): return np.maximum(0, 4/6 - x)
def h4(x): return np.maximum(0, - 5/6 + x)

# Define the final output y(x)
y = 1.4 - 3* h1(x) + 2 *h2(x) - 2* h3(x) + 4  * h4(x)

# Plot the function
plt.figure(figsize=(8, 4))
plt.plot(x, y, color='darkorange')
plt.axhline(0, color='gray', linestyle='--', linewidth=0.5)
plt.axvline(1/6, color='lightgray', linestyle='--')
plt.axvline(2/6, color='lightgray', linestyle='--')
plt.axvline(4/6, color='lightgray', linestyle='--')
plt.axvline(5/6, color='lightgray', linestyle='--')
plt.title("Output of ReLU Network (4 Linear Regions)")
plt.xlabel("Input $x$")
plt.ylabel("Output $y$")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Problem 10

# %% [markdown]
# We have:
# - One input
# - One output
# - \( K \) hidden layers
# - \( D \) hidden units per hidden layer
#
# ---
#
# **1. Input → First hidden layer**
# Each of the \( D \) neurons receives:
# - 1 weight from the input
# - 1 bias
#
# So:
# $$
# \text{Parameters} = D + D = 2D
# $$
#
# ---
#
# **2. Between hidden layers (from layer 1 to layer \( K - 1 \))**
# Each layer has:
# - \( D \times D \) weights
# - \( D \) biases
#
# There are \( K - 1 \) such connections:
#
# $$
# \text{Parameters} = (K - 1)(D^2 + D)
# $$
#
# ---
#
# **3. Last hidden layer → Output layer**
# - \( D \) weights
# - 1 bias
#
# $$
# \text{Parameters} = D + 1
# $$
#
# ---
#
# **Total:**
# $$
# 2D + (K - 1)(D^2 + D) + D + 1
# $$
#
# Group like terms:
# $$
# = (K - 1)(D^2 + D) + 3D + 1
# $$
#
# ---
#
# ### ✅ Final Answer:
#
# $$
# \boxed{3D + 1 + (K - 1)D(D + 1)}
# $$

# %% [markdown]
# ## Problem 11

# %% [markdown]
# We compare two neural networks:
#
# - **Shallow**: 1 hidden layer with \( D = 95 \) units
# - **Deep**: \( K = 10 \) layers, each with \( D = 5 \) units
#
# ---
#
# ### 1️⃣ Parameter Count
#
# **Both networks** have the same number of parameters:
# Use formula from Problem 4.10:
#
# $$
# \text{Total Parameters} = 3D + 1 + (K - 1)D(D + 1)
# $$
#
# For both networks:
# - Shallow: \( D = 95, K = 1 \)
#   $$
#   3 \cdot 95 + 1 + 0 = 286
#   $$
# - Deep: \( D = 5, K = 10 \)
#   $$
#   3 \cdot 5 + 1 + 9 \cdot 5 \cdot 6 = 15 + 1 + 270 = 286
#   $$
#
# ✅ Both networks have **286 parameters**.
#
# ---
#
# ### 2️⃣ Linear Region Count (Equation 4.17)
#
# Equation:
#
# $$
# N_r = \left( \frac{D}{D_i} + 1 \right)^{D_i(K - 1)} \cdot \sum_{j=0}^{D_i} \binom{D}{j}
# $$
#
# #### 🔹 Shallow Network:
# - \( D_i = 1, D = 95, K = 1 \)
# - One hidden layer: max regions =
#
# $$
# \sum_{j=0}^{1} \binom{95}{j} = \binom{95}{0} + \binom{95}{1} = 1 + 95 = \boxed{96}
# $$
#
# #### 🔹 Deep Network:
# - \( D_i = 1, D = 5, K = 10 \)
#
# $$
# N_r = \left( \frac{5}{1} + 1 \right)^9 \cdot \left( \binom{5}{0} + \binom{5}{1} \right)
# = 6^9 \cdot (1 + 5) = 6^9 \cdot 6 = 6^{10}
# = \boxed{60,\!466,\!176 \text{ linear regions}}
# $$
#
# ---
#
# ### 3️⃣ Speed Comparison
#
# - Shallow network: ✅ **Faster** (only 1 layer)
# - Deep network: ❌ **Slower** (10 layers = more computation)
#
# ---
#
# ### ✅ Final Summary
#
# | Feature              | Shallow (D = 95) | Deep (K = 10, D = 5)        |
# |----------------------|------------------|-----------------------------|
# | **# Parameters**     | 286              | 286                         |
# | **Linear Regions**   | ~96              | 60,466,176                  |
# | **Speed (per input)**| ✅ Faster         | ❌ Slower                   |
# | **Expressiveness**   | ❌ Limited        | ✅ Extremely high           |

# %% [markdown]
# # Section 5

# %% [markdown]
# ## Problem 1

# %% [markdown]
# The sigmoid function is defined as:
#
# $$
# \text{sig}[z] = \frac{1}{1 + \exp(-z)}
# $$
#
# We want to show:
#
# - \( \text{sig}[z] \to 0 \) as \( z \to -\infty \)
# - \( \text{sig}[z] = 0.5 \) when \( z = 0 \)
# - \( \text{sig}[z] \to 1 \) as \( z \to +\infty \)
#
# ---
#
# **1. When \( z = 0 \):**
#
# $$
# \text{sig}[0] = \frac{1}{1 + e^0} = \frac{1}{2} = 0.5
# $$
#
# ✅ Proven.
#
# ---
#
# **2. As \( z \to \infty \):**
#
# $$
# \exp(-z) \to 0 \Rightarrow \text{sig}[z] \to \frac{1}{1 + 0} = 1
# $$
#
# ✅ Proven.
#
# ---
#
# **3. As \( z \to -\infty \):**
#
# $$
# \exp(-z) \to \infty \Rightarrow \text{sig}[z] \to \frac{1}{1 + \infty} = 0
# $$
#
# ✅ Proven.

# %% [markdown]
# ## Problem 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid network output values
s = np.linspace(1e-6, 1 - 1e-6, 500)  # Avoid log(0)

# Loss function for y = 0 and y = 1
loss_y0 = -np.log(1 - s)      # when y = 0
loss_y1 = -np.log(s)          # when y = 1

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(s, loss_y0, label="Loss when y = 0", color="blue")
plt.plot(s, loss_y1, label="Loss when y = 1", color="red")
plt.title("Binary Cross-Entropy Loss vs Sigmoid Output")
plt.xlabel("sig[f(x, φ)]")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Problem 3

# %% [markdown]
# We are modeling wind direction $ y \in [0, 2\pi) $ using a von Mises distribution:
#
# $$
# Pr(y \mid \mu, \kappa) = \frac{\exp(\kappa \cos(y - \mu))}{2\pi I_0(\kappa)}
# $$
#
# Let $ \mu = f(\mathbf{x}, \phi) $, predicted by a neural network from input $ \mathbf{x} $.
#
# ---
#
# ### ✅ Loss Function
#
# We minimize the **negative log-likelihood** of the von Mises distribution:
#
# $$
# L(\phi) = -\log Pr(y \mid f(\mathbf{x}, \phi), \kappa)
# = -\kappa \cos(y - f(\mathbf{x}, \phi)) + \log(2\pi I_0(\kappa))
# $$
#
# Since $ \kappa $ is constant, the loss simplifies to:
#
# $$
# \boxed{L(\phi) = -\cos(y - f(\mathbf{x}, \phi))}
# \quad \text{(ignoring constants)}
# $$
#
#
# $$
# \cos(y - \mu)
# $$
#
# achieves its **maximum when** $ y = \mu $, the distribution is also **maximized** at:
#
# $$
# \boxed{y = \mu}
# $$
#
# So the **mode** (most likely value) of the von Mises distribution is exactly $ \mu $.
#
#
# ---
#
# ### ✅ Inference
#
# Once trained, the most likely prediction for $ y $ given $ \mathbf{x} $ is:
#
# $$
# \boxed{\hat{y} = f(\mathbf{x}, \phi)}
# $$
#
# This is the **mode** of the von Mises distribution.

# %% [markdown]
# ## Problem 4

# %% [markdown]
# We model $ y \in \mathbb{R} $ given input $ x $ using a **mixture of two Gaussians**:
#
# $$
# Pr(y \mid x) = \lambda \cdot \mathcal{N}(y \mid \mu_1, \sigma_1^2) + (1 - \lambda) \cdot \mathcal{N}(y \mid \mu_2, \sigma_2^2)
# $$
#
# Here, $ \mathcal{N}(y \mid \mu, \sigma^2) $ refers to the **Gaussian (normal) probability density function**, defined as:
#
# $$
# \mathcal{N}(y \mid \mu, \sigma^2) = \frac{1}{\sqrt{2\pi \sigma^2}} \exp\left(-\frac{(y - \mu)^2}{2\sigma^2}\right)
# $$
#
# ---
#
# ### ✅ Loss Function
#
# Use the **negative log-likelihood** over $ I $ training examples:
#
# $$
# \mathcal{L}(\phi) = -\sum_{i=1}^I \log\left[
# \lambda_i \cdot \mathcal{N}(y_i \mid \mu_{1i}, \sigma_{1i}^2) + (1 - \lambda_i) \cdot \mathcal{N}(y_i \mid \mu_{2i}, \sigma_{2i}^2)
# \right]
# $$
#
# where all parameters $ \lambda_i, \mu_{1i}, \mu_{2i}, \sigma_{1i}, \sigma_{2i} $ are predicted by the model $ f(x_i, \phi) $.
#
# ---
#
# ### ❗ Inference Challenges
#
# - **Multimodality**: There may be two plausible outputs $ \mu_1, \mu_2 $ . Which one do you pick?
# - **Ambiguity**: Choosing only the most likely mode may discard useful information.
# - **Mode collapse**: The model might default to using just one component (e.g., $ \lambda \to 1 $).
# - **Numerical instability**: Very small variances can cause sharp peaks, leading to unstable gradients.
#
# ---
#
# ### ✅ Inference Strategy
#
# Once trained, given a new $ x $, the model outputs:
#
# $$
# (\lambda, \mu_1, \mu_2, \sigma_1, \sigma_2)
# $$
#
# You may:
# - Return the most likely mode:
#   $$
#   \hat{y} = \begin{cases}
#   \mu_1 & \text{if } \lambda > 0.5 \\
#   \mu_2 & \text{otherwise}
#   \end{cases}
#   $$
# - Sample from the mixture distribution
# - Return both modes (if downstream task can use them)

# %% [markdown]
# ## Problem 5

# %% [markdown]
# We extend the model from Problem 5.3 to use a **mixture of two von Mises distributions** to model circular outputs.
#
# ---
#
# ### ✅ Likelihood Expression
#
# Let:
#
# - $ \lambda \in [0, 1] $: weight of the first component
# - $ \mu_1, \mu_2 $: mean directions
# - $ \kappa_1, \kappa_2 $: concentration parameters
#
# Then:
#
# $$
# Pr(y \mid \theta) = \lambda \cdot \text{VM}(y \mid \mu_1, \kappa_1) + (1 - \lambda) \cdot \text{VM}(y \mid \mu_2, \kappa_2)
# $$
#
# Using the von Mises density:
#
# $$
# Pr(y \mid \theta) =
# \lambda \cdot \frac{1}{2\pi I_0(\kappa_1)} \exp\left( \kappa_1 \cos(y - \mu_1) \right) +
# (1 - \lambda) \cdot \frac{1}{2\pi I_0(\kappa_2)} \exp\left( \kappa_2 \cos(y - \mu_2) \right)
# $$
#
# ---
#
# ### ✅ Number of Network Outputs
#
# The network must predict:
#
# - $ \lambda $ (1 output)
# - $ \mu_1 $, $ \mu_2 $ (2 outputs)
# - $ \kappa_1 $, $ \kappa_2 $ (2 outputs)
#
# So the network must output:
#
# $$
# \boxed{5 \text{ values: } \lambda, \mu_1, \kappa_1, \mu_2, \kappa_2}
# $$

# %% [markdown]
# ## Problem 6

# %% [markdown]
# We want to predict the number of pedestrians $ y \in \{0, 1, 2, \dots\} $ passing a location using input$ \mathbf{x} $ (time, coordinates, neighborhood).
#
# We model $ y $ using a **Poisson distribution**:
#
# $$
# Pr(y = k \mid \lambda) = \frac{\lambda^k e^{-\lambda}}{k!}
# $$
#
# ---
#
# ### ✅ Model Output
#
# Let the network predict the **rate parameter**:
#
# $$
# \lambda_i = f(\mathbf{x}_i, \phi)
# $$
#
# where $ \lambda_i > 0 $ is the expected count for input $ \mathbf{x}_i $.
#
# ---
#
# ### ✅ Loss Function
#
# We minimize the **negative log-likelihood** over $ I $ data points:
#
# $$
# \mathcal{L}(\phi) = -\sum_{i=1}^I \log \left( \frac{\lambda_i^{y_i} e^{-\lambda_i}}{y_i!} \right)
# = \sum_{i=1}^I \left( \lambda_i - y_i \log \lambda_i + \log(y_i!) \right)
# $$
#
# Since $\log(y_i!) $ is constant w.r.t. $ \phi $, we simplify to:
#
# $$
# \boxed{
# \mathcal{L}(\phi) = \sum_{i=1}^I \left( \lambda_i - y_i \log \lambda_i \right) + \text{const}
# }
# $$
#
# ---
#
# ### ⚠️ Implementation Note
#
# Ensure $ \lambda_i > 0 $ using:
# - `softplus` activation: $ \lambda = \log(1 + e^z) $

# %% [markdown]
# ## Problem 7

# %% [markdown]
# We model $ \mathbf{y} \in \mathbb{R}^{10} $ using 10 independent normal distributions:
#
# $$
# y_d \sim \mathcal{N}(\mu_d, \sigma^2)
# $$
#
# Where:
# - $ \mu_d $ is predicted by the model: $ \mu = f(\mathbf{x}, \phi) $
# - $ \sigma^2 $ is constant (not learned)
#
# ---
#
# ### ✅ Likelihood
#
# The total likelihood is:
#
# $$
# Pr(\mathbf{y} \mid f(\mathbf{x}, \phi)) =
# \prod_{d=1}^{10} \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left( -\frac{(y_d - \mu_d)^2}{2\sigma^2} \right)
# $$
#
# ---
#
# ### ✅ Negative Log-Likelihood
#
# $$
# \mathcal{L}(\phi) = \sum_{d=1}^{10} \left[ \frac{(y_d - \mu_d)^2}{2\sigma^2} + \frac{1}{2} \log(2\pi\sigma^2) \right]
# $$
#
# $$
# = \frac{1}{2\sigma^2} \sum_{d=1}^{10} (y_d - \mu_d)^2 + \text{const}
# $$
#
# ---
#
# ### ✅ Conclusion
#
# Minimizing the negative log-likelihood is equivalent to minimizing:
#
# $$
# \boxed{ \sum_{d=1}^{10} (y_d - \mu_d)^2 }
# $$
#
# which is the **sum of squared errors**, when $ \sigma^2 $ is fixed.

# %% [markdown]
# ## Problem 9

# %% [markdown]
# We predict:
# - Height in meters (~1.6–2.0)
# - Weight in kilograms (~50–150)
#
# ---
#
# ### ❗ Problems Caused by Different Scales
#
# 1. **Loss imbalance**: Larger-magnitude targets (e.g., weight) dominate the loss, making the model biased toward predicting those better.
# 2. **Gradient imbalance**: Larger outputs produce larger gradients, potentially destabilizing or slowing training for smaller targets.
#
# ---
#
# ### ✅ Solution 1: Normalize the Targets
#
# Standardize each output to have zero mean and unit variance:
#
# $$
# \tilde{y}_d = \frac{y_d - \mu_d}{\sigma_d}
# $$
#
# Then invert this transformation after prediction.
#
# ---
#
# ### ✅ Solution 2: Weighted Loss Function
#
# Use weights in the loss function to balance target scales:
#
# $$
# \text{Loss} = \alpha \cdot (y_{\text{height}} - \hat{y}_{\text{height}})^2 + \beta \cdot (y_{\text{weight}} - \hat{y}_{\text{weight}})^2
# $$
#
# where $ \alpha, \beta $ are chosen based on inverse target variance or importance.
#
# ---
#
# Both approaches ensure balanced training and fair optimization of all targets.

# %% [markdown]
# ## Problem 10

# %% [markdown]
# We want to predict:
#
# - $ y_\theta \in [0, 2\pi) $: wind direction (circular)
# - $ y_s \in \mathbb{R}^{+} $: wind speed (positive real)
#
# ---
#
# ### ✅ Wind Direction: von Mises Distribution
#
# Assume:
#
# $$
# Pr(y_\theta \mid \mu_\theta, \kappa) = \frac{1}{2\pi I_0(\kappa)} \exp\left( \kappa \cos(y_\theta - \mu_\theta) \right)
# $$
#
# Loss:
#
# $$
# \mathcal{L}_{\text{dir}} = -\kappa \cos(y_\theta - \mu_\theta)
# $$
#
# ---
#
# ### ✅ Wind Speed: Gaussian
#
# Assume:
#
# $$
# y_s \sim \mathcal{N}(\mu_s, \sigma^2)
# $$
#
# Loss:
#
# $$
# \mathcal{L}_{\text{speed}} = \frac{1}{2\sigma^2} (y_s - \mu_s)^2
# $$
#
# ---
#
# ### ✅ Total Loss Function
#
# Combined:
#
# $$
# \mathcal{L} = -\kappa \cos(y_\theta - \mu_\theta) + \frac{1}{2\sigma^2} (y_s - \mu_s)^2 + \text{const}
# $$
#
# ---
#
# ### ✅ Network Outputs
#
# - $ \mu_\theta $: predicted mean wind direction
# - $ \mu_s $: predicted wind speed
#
# (Optional: $ \kappa $, $ \sigma^2 $ if modeling heteroscedasticity)

# %% [markdown]
# # Section 6

# %% [markdown]
# ## Problem 1

# %% [markdown]
# We are given the per-sample loss:
#
# $$
# \ell_i = (\phi_0 + \phi_1 x_i - y_i)^2
# $$
#
# Let’s define the **residual** as:
#
# $$
# r_i = \phi_0 + \phi_1 x_i - y_i
# $$
#
# This is the difference between the predicted output $ \hat{y}_i = \phi_0 + \phi_1 x_i $ and the true label $ y_i $.
# So: $r_i = \hat{y}_i - y_i $
#
# ---
#
# ### ✅ Derivative w.r.t. \( \phi_0 \)
#
# We apply the chain rule:
#
# $$
# \frac{\partial \ell_i}{\partial \phi_0} = \frac{\partial}{\partial \phi_0} (r_i^2) = 2r_i \cdot \frac{\partial r_i}{\partial \phi_0}
# $$
#
# Now compute:
#
# $$
# \frac{\partial r_i}{\partial \phi_0} = \frac{\partial}{\partial \phi_0} (\phi_0 + \phi_1 x_i - y_i)
# $$
#
# - $ \frac{\partial \phi_0}{\partial \phi_0} = 1 $
# - $ \phi_1 x_i $ is constant w.r.t. $ \phi_0 $ → derivative = 0
# - $ y_i $ is constant → derivative = 0
#
# So:
#
# $$
# \frac{\partial r_i}{\partial \phi_0} = 1
# $$
#
# Thus:
#
# $$
# \frac{\partial \ell_i}{\partial \phi_0} = 2(\phi_0 + \phi_1 x_i - y_i)
# $$
#
# ---
#
# ### ✅ Derivative w.r.t. \( \phi_1 \)
#
# Same procedure:
#
# $$
# \frac{\partial \ell_i}{\partial \phi_1} = \frac{\partial}{\partial \phi_1} (r_i^2) = 2r_i \cdot \frac{\partial r_i}{\partial \phi_1}
# $$
#
# Now compute:
#
# $$
# \frac{\partial r_i}{\partial \phi_1} = \frac{\partial}{\partial \phi_1} (\phi_0 + \phi_1 x_i - y_i) = x_i
# $$
#
# So:
#
# $$
# \frac{\partial \ell_i}{\partial \phi_1} = 2r_i \cdot x_i = 2x_i(\phi_0 + \phi_1 x_i - y_i)
# $$
#
# ---
#
# ### ✅ Final Gradient Expression
#
# $$
# \frac{\partial \ell_i}{\partial \phi} =
# \begin{bmatrix}
# 2(\phi_0 + \phi_1 x_i - y_i) \\
# 2x_i(\phi_0 + \phi_1 x_i - y_i)
# \end{bmatrix}
# $$
#
# This matches exactly with Equation (6.7).

# %% [markdown]
# ## Problem 2

# %% [markdown]
# We are given the loss:
#
# $$
# L[\phi] = \sum_{i=1}^I (\phi_0 + \phi_1 x_i - y_i)^2
# $$
#
# ---
#
# ### ✅ Hessian Matrix
#
# We compute:
#
# $$
# \mathbf{H}[\phi] =
# \begin{bmatrix}
# \frac{\partial^2 L}{\partial \phi_0^2} & \frac{\partial^2 L}{\partial \phi_0 \partial \phi_1} \\
# \frac{\partial^2 L}{\partial \phi_1 \partial \phi_0} & \frac{\partial^2 L}{\partial \phi_1^2}
# \end{bmatrix}
# =
# \begin{bmatrix}
# 2I & 2 \sum x_i \\
# 2 \sum x_i & 2 \sum x_i^2
# \end{bmatrix}
# $$
#
# ---
#
# ### ✅ Convexity Proof
#
# #### Trace:
#
# $$
# \text{Tr}(\mathbf{H}) = 2I + 2 \sum x_i^2 > 0
# $$
#
# #### Determinant:
#
# $$
# \det(\mathbf{H}) = 4 \left( I \sum x_i^2 - (\sum x_i)^2 \right) > 0
# $$
#
# (based on the Cauchy–Schwarz inequality)
#
# ---
#
# ✅ Therefore, all eigenvalues are positive, so the function is **convex** and has a **unique global minimum**.
